# %% [markdown]
# # BEST STREAMING SERVICES ANALYSIS

# %% [markdown]
# #### **Importing The Required Modules**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat
import plotly.express as px
import plotly.io as pio

# %% [markdown]
# #### **Loading The Dataset**

# %%
ott = pd.read_csv("moviestreams.csv")

# %%
ott.sample(3)
# Out:
#        Unnamed: 0     ID             Title  Year  Age  IMDb Rotten Tomatoes  \
# 14156       14156  14157          Bad Meat  2011  18+   3.5             NaN
# 13022       13022  13023      Los Marcados  1971  NaN   6.3             NaN
# 12211       12211  12212  This Is a Hijack  1973   7+   5.6             NaN
#
#        Netflix  Hulu  Prime Video  Disney+  Type         Directors  \
# 14156        0     0            1        0     0       Lulu Jarmen
# 13022        0     0            1        0     0  Alberto Mariscal
# 12211        0     0            1        0     0     Barry Pollack
#
#                        Genres        Country Language  Runtime
# 14156           Comedy,Horror         Canada  English     92.0
# 13022  Drama,Thriller,Western         Mexico  Spanish     85.0
# 12211    Crime,Thriller,Drama  United States  English     90.0

# %%
ott.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
ott.tail()
# Out:
#        Unnamed: 0     ID                      Title  Year  Age  IMDb  \
# 16739       16739  16740  The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741             The Poof Point  2001   7+   4.7
# 16741       16741  16742      Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743         Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744           In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 16739             NaN        0     0            0        1     0
# 16740             NaN        0     0            0        1     0
# 16741             NaN        0     0            0        1     0
# 16742             NaN        0     0            0        1     0
# 16743             NaN        0     0            0        1     0
#
#                   Directors                        Genres        Country  \
# 16739          Bruce Bilson  Comedy,Family,Fantasy,Horror  United States
# ...

# %% [markdown]
# #### **Shape Of The Dataset**

# %%
print("The Shape Of The Dataset is :",ott.shape)
# Out:
# The Shape Of The Dataset is : (16744, 17)

# %% [markdown]
# #### **The Info About The Dataset**

# %%
ott.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %% [markdown]
# #### **Dataset Columns Names**

# %%
cols = ott.columns.tolist()
cols
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Title',
#  'Year',
#  'Age',
#  'IMDb',
#  'Rotten Tomatoes',
#  'Netflix',
#  'Hulu',
#  'Prime Video',
#  'Disney+',
#  'Type',
#  'Directors',
#  'Genres',
#  'Country',
#  'Language',
#  'Runtime']

# %% [markdown]
# #### **Droping Unwanted Columns In The Dataset**

# %%
ott.drop(["Unnamed: 0","ID", "Type"],axis=1,inplace=True)
cols = ott.columns.tolist()
cols
# Out:
# ['Title',
#  'Year',
#  'Age',
#  'IMDb',
#  'Rotten Tomatoes',
#  'Netflix',
#  'Hulu',
#  'Prime Video',
#  'Disney+',
#  'Directors',
#  'Genres',
#  'Country',
#  'Language',
#  'Runtime']

# %%
ott.head()
# Out:
#                             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8             87%        1
# 1                      The Matrix  1999  18+   8.7             87%        1
# 2          Avengers: Infinity War  2018  13+   8.5             84%        1
# 3              Back to the Future  1985   7+   8.5             96%        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             97%        1
#
#    Hulu  Prime Video  Disney+                       Directors  \
# 0     0            0        0               Christopher Nolan
# 1     0            0        0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0         Anthony Russo,Joe Russo
# 3     0            0        0                 Robert Zemeckis
# 4     0            1        0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %% [markdown]
# #### **Checking For Null Values**

# %%
ott.isna()
# Out:
#        Title   Year    Age   IMDb  Rotten Tomatoes  Netflix   Hulu  \
# 0      False  False  False  False            False    False  False
# 1      False  False  False  False            False    False  False
# 2      False  False  False  False            False    False  False
# 3      False  False  False  False            False    False  False
# 4      False  False  False  False            False    False  False
# ...      ...    ...    ...    ...              ...      ...    ...
# 16739  False  False   True  False             True    False  False
# 16740  False  False  False  False             True    False  False
# 16741  False  False   True  False             True    False  False
# 16742  False  False   True  False             True    False  False
# 16743  False  False   True   True             True    False  False
#
#        Prime Video  Disney+  Directors  Genres  Country  Language  Runtime
# 0            False    False      False   False    False     False    False
# ...

# %%
ott.isnull().sum()
# Out:
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Directors            726
# Genres               275
# Country              435
# Language             614
# Runtime              592
# dtype: int64

# %% [markdown]
# ### **Modifying Age**
#
# **Null Values and mapping that string format  into the float type by adding new columnname : age**

# %%
ott["Age"].unique()
# Out:
# array(['13+', '18+', '7+', nan, 'all', '16+'], dtype=object)

# %%
ott["Age"].value_counts()
# Out:
# Age
# 18+    3474
# 7+     1462
# 13+    1255
# all     843
# 16+     320
# Name: count, dtype: int64

# %%
age_map={'13+':13, '18+':18, '7+':7, 'all':0, '16+':16}
ott['age'] = ott['Age'].map(age_map)
ott['age']
# Out:
# 0        13.0
# 1        18.0
# 2        13.0
# 3         7.0
# 4        18.0
#          ...
# 16739     NaN
# 16740     7.0
# 16741     NaN
# 16742     NaN
# 16743     NaN
# Name: age, Length: 16744, dtype: float64

# %% [markdown]
# #### **Converting Rotten Tomatoes column into the float datatype**

# %%
ott['Rotten Tomatoes'] = ott['Rotten Tomatoes'].str.replace("%","")
ott['Rotten Tomatoes'] = ott['Rotten Tomatoes'].astype(float)

# %%
ott['Rotten Tomatoes']
# Out:
# 0        87.0
# 1        87.0
# 2        84.0
# 3        96.0
# 4        97.0
#          ...
# 16739     NaN
# 16740     NaN
# 16741     NaN
# 16742     NaN
# 16743     NaN
# Name: Rotten Tomatoes, Length: 16744, dtype: float64

# %%
ott['Age'].value_counts()
# Out:
# Age
# 18+    3474
# 7+     1462
# 13+    1255
# all     843
# 16+     320
# Name: count, dtype: int64

# %%
ott.isnull().sum()
# Out:
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Directors            726
# Genres               275
# Country              435
# Language             614
# Runtime              592
# age                 9390
# dtype: int64

# %% [markdown]
#  **Dropping Null values in Directors , Genres , Country , Language columns in the dataset**

# %%
'''ott.dropna(subset = ['Age'],inplace=True)

ott.dropna(subset = ['IMDb'],inplace=True)

ott.dropna(subset = ['Rotten Tomatoes'],inplace =True)

ott.dropna(subset = ['Directors'],inplace=True)

ott.dropna(subset = ['Genres'],inplace=True)


ott.dropna(subset = ['Country'],inplace=True)

ott.dropna(subset = ['Language'],inplace=True)

ott.isnull().sum()
'''
ott.dropna(inplace=True)

# %%
len(ott)
# Out:
# 3299

# %%
ott.isnull().sum()
# Out:
# Title              0
# Year               0
# Age                0
# IMDb               0
# Rotten Tomatoes    0
# Netflix            0
# Hulu               0
# Prime Video        0
# Disney+            0
# Directors          0
# Genres             0
# Country            0
# Language           0
# Runtime            0
# age                0
# dtype: int64

# %%
ott.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3299 entries, 0 to 16705
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            3299 non-null   object
#  1   Year             3299 non-null   int64
#  2   Age              3299 non-null   object
#  3   IMDb             3299 non-null   float64
#  4   Rotten Tomatoes  3299 non-null   float64
#  5   Netflix          3299 non-null   int64
#  6   Hulu             3299 non-null   int64
#  7   Prime Video      3299 non-null   int64
#  8   Disney+          3299 non-null   int64
#  9   Directors        3299 non-null   object
#  10  Genres           3299 non-null   object
#  11  Country          3299 non-null   object
#  12  Language         3299 non-null   object
#  13  Runtime          3299 non-null   float64
#  14  age              3299 non-null   float64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 412.4+ KB

# %% [markdown]
# **Checking and Droping Duplicate Values (If they are)**

# %%
ott.duplicated().sum()
# Out:
# 0

# %%
ott = ott.drop_duplicates()
print("The length of the dataset after droping duplicates: ",len(ott))

# There are no duplicate values in the dataset so the length remains constant
# Out:
# The length of the dataset after droping duplicates:  3299

# %% [markdown]
# **Description Of The Dataset**

# %%
ott.describe()
# Out:
#               Year         IMDb  Rotten Tomatoes      Netflix         Hulu  \
# count  3299.000000  3299.000000      3299.000000  3299.000000  3299.000000
# mean   2006.160958     6.349864        61.125493     0.303122     0.129736
# std      14.516876     0.991615        27.120925     0.459677     0.336064
# min    1902.000000     1.600000         2.000000     0.000000     0.000000
# 25%    2002.000000     5.700000        40.000000     0.000000     0.000000
# 50%    2011.000000     6.400000        66.000000     0.000000     0.000000
# 75%    2016.500000     7.100000        85.000000     1.000000     0.000000
# max    2020.000000     9.000000       100.000000     1.000000     1.000000
#
#        Prime Video      Disney+      Runtime          age
# count   3299.00000  3299.000000  3299.000000  3299.000000
# mean       0.54562     0.101243   102.682631    13.525614
# std        0.49799     0.301696    19.491572     5.697674
# min        0.00000     0.000000    11.000000     0.000000
# ...

# %% [markdown]
# ## **VISUALIZATION**

# %% [markdown]
# #### **TOP 10 LANGUAGES IN STREAMING SERVICES**

# %%
ott["Language"].value_counts()
# Out:
# Language
# English                                            2196
# English,Spanish                                     125
# English,French                                       80
# Hindi                                                55
# English,German                                       31
#                                                    ...
# English,Mandarin,Spanish                              1
# English,Yiddish,German                                1
# English,Esperanto                                     1
# French,Italian                                        1
# Chinese,Mandarin,Japanese,Korean,French,English       1
# Name: count, Length: 437, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

language = ott['Language'].value_counts().head(10)
colors = ["blue", "red", "silver", "green", "cyan", "magenta", "black", "grey", "purple", "gold"]

plt.figure(figsize=(14, 6))
sns.barplot(x=language.index, y=language.values, palette=colors)
plt.title("Top 10 Languages in Streaming Services")
plt.xlabel("Languages")
plt.ylabel("Count of Movies")

# Adding values on top of the bars with a slight offset
for i, value in enumerate(language.values):
    plt.text(i, value+10, str(value), ha='center', fontsize=15)

plt.show()

# %% [markdown]
# #### **TOP 10 COUNTRIES IN STREAMING SERVICES**

# %%
ott['Country'].value_counts()
# Out:
# Country
# United States                                             1820
# United Kingdom                                             152
# India                                                       96
# United Kingdom,United States                                87
# Canada                                                      74
#                                                           ...
# France,Spain,Romania,Belgium,United States                   1
# Iran,France,Iraq                                             1
# Denmark,Sweden,France,Germany                                1
# Australia,United States,United Kingdom,India,Singapore       1
# United States,Hungary,United Kingdom                         1
# Name: count, Length: 509, dtype: int64

# %%
country = ott['Country'].value_counts().head(10)
colors = [ "red", "silver", "green", "cyan", "grey", "magenta", "black", "purple", "gold","blue",]

plt.figure(figsize=(12, 6))
sns.barplot(x=country.index, y=country.values, palette=colors)

plt.title("Top 10 Countries in Streaming Services")
plt.xlabel("Countries")
plt.ylabel("Values")

for i, value in enumerate(country.values):
    plt.text(i, value + 5, str(value), ha='center', fontsize=15)

plt.show()

# %% [markdown]
# #### **Movies Present in Each Streaming Services**

# %%
print(ott['Netflix'].sum())
print(ott['Hulu'].sum())
print(ott['Prime Video'].sum())
print(ott['Disney+'].sum())
# Out:
# 1000
# 428
# 1800
# 334

# %%
s = {
    'Netflix': 1000,
    'Hulu': 428,
    'Prime Video': 1802,
    'Disney+': 334
}

b = list(s.keys())
c = list(s.values())

colors = ["blue", "red", "green", "violet"]

plt.figure(figsize=(10, 6))
sns.barplot(x=b, y=c, palette=colors)

plt.title("Number of Movies Present In Each Streaming Service")
plt.xlabel("Streaming Services")
plt.ylabel("No of Movies")

for i, value in enumerate(c):
    plt.text(i, value + 5, str(value), ha='center', fontsize=15)

plt.show()
# Out:
# C:\Users\sivaa\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning:
#
# unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.

# %% [markdown]
# #### **Number Of Movies In Specific Age Group**

# %%
ott["Age"].value_counts()
# Out:
# Age
# 18+    1681
# 13+     665
# 7+      602
# all     257
# 16+      94
# Name: count, dtype: int64

# %%
a = ott['Age'].value_counts()
plt.figure(figsize=(12, 6))
sns.barplot(x=a.index, y=a.values, palette=colors)

plt.title('Number Of Movies In Specific Age Group In All Streaming Services')
plt.xlabel('Age')
plt.ylabel('Number of Movies')

for i, value in enumerate(a.values):
    plt.text(i, value+5, str(value), ha='center', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(a.values, labels=a.index, autopct='%1.1f%%')

plt.title("Percentage of Movies In Specific Age Group In All Series")

plt.show()

# %% [markdown]
# #### **Number Of Movies In Specific Age Group In Netflix**

# %%
netflix = ott[ott['Netflix'] == 1]
netflix['Age'].value_counts()
# Out:
# Age
# 18+    526
# 13+    239
# 7+     167
# 16+     42
# all     26
# Name: count, dtype: int64

# %%
b = netflix['Age'].value_counts()
plt.figure(figsize=(10, 6))

sns.barplot(x=b.index, y=b.values, palette=colors)

plt.title('Number Of Movies In Specific Age Group In Netflix')
plt.xlabel('Age')
plt.ylabel('Number of Movies in Netflix')

for i, value in enumerate(b.values):
    plt.text(i, value+5, str(value), ha='center', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(b.values, labels=b.index, autopct='%1.1f%%')

plt.title("Percentage Of Movies In Specific Age Group In Netflix")

plt.show()

# %% [markdown]
# #### **Number Of Movies In Specific Age Group In Amazon Prime Video**

# %%
amazon_prime = ott[ott['Prime Video'] == 1]
amazon_prime['Age'].value_counts()
# Out:
# Age
# 18+    1039
# 13+     368
# 7+      276
# all      66
# 16+      51
# Name: count, dtype: int64

# %%
disney = ott[ott['Disney+'] == 1]
disney['Age'].value_counts()
# Out:
# Age
# all    161
# 7+     135
# 13+     36
# 18+      1
# 16+      1
# Name: count, dtype: int64

# %%
hulu = ott[ott['Hulu'] == 1]
hulu['Age'].value_counts()
# Out:
# Age
# 18+    243
# 13+    100
# 7+      74
# all      8
# 16+      3
# Name: count, dtype: int64

# %%
c = amazon_prime["Age"].value_counts()

colors = ["blue", "red", "green", "violet", "orange"]

plt.figure(figsize=(10, 6))
sns.barplot(x=c.index, y=c.values, palette=colors)

plt.title("Number Of Movies In Specific Age Group In Amazon Prime Video")
plt.xlabel("Age Group")
plt.ylabel("Number of Movies Amazon Prime Video")

for i, value in enumerate(c.values):
    plt.text(i, value + 5, str(value), ha='center', fontsize=15)

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(c.values, labels=c.index, autopct='%1.1f%%')

plt.title("Percentage Of Movies In Specific Age Group In Amazon Prime Video")

plt.show()

# %% [markdown]
# #### **Number Of Movies In Specific Age Group In Disney+**

# %%
d = disney["Age"].value_counts()

colors = ["blue", "red", "green", "violet", "orange"]

plt.figure(figsize=(10, 6))
sns.barplot(x=d.index, y=d.values, palette=colors)

plt.title("Number Of Movies In Specific Age Group In Disney+")
plt.xlabel("Age Group")
plt.ylabel("Number of Movies in Disney+")

for i, value in enumerate(d.values):
    plt.text(i, value, str(value), ha='center', fontsize=11)

plt.show()

# %% [markdown]
# #### **Number Of Movies In Specific Age Group In Hulu**

# %%
e = hulu['Age'].value_counts()

colors = ["blue", "red", "green", "violet", "orange"]

plt.figure(figsize=(10, 6))
sns.barplot(x=e.index, y=e.values, palette=colors)

plt.title("Number Of Movies In Specific Age Group In Hulu")
plt.xlabel("Age Group")
plt.ylabel("Number of Movies")

for i, value in enumerate(e.values):
    plt.text(i, value, str(value), ha='center', fontsize=11)

plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(e.values, labels=e.index, autopct='%1.1f%%')

plt.title("Percentage Of Movies In Specific Age Group In Disney+")

plt.show()

# %% [markdown]
# #### **Relation Between IMDB ratings and Rotten Tomatoes rattings**

# %%
plt.figure(figsize=(12, 4))
sns.scatterplot(x=ott['IMDb'], y=ott['Rotten Tomatoes'], color='red')

plt.title("Relation Between IMDb and Rotten Tomatoes")
plt.xlabel("IMDb")
plt.ylabel("Rotten Tomatoes")

plt.show()

# %% [markdown]
# #### **Relationship Between Runtime and IMDb ratings**

# %%
plt.figure(figsize=(12, 4))
sns.scatterplot(x=ott['Runtime'], y=ott['IMDb'], color='black')

plt.title("Relation Between Runtime and IMDb")
plt.xlabel("Runtime")
plt.ylabel("IMDb")

plt.show()

# %% [markdown]
# #### **Relationship Between Runtime and IMDb Rotten Tomatoes ratings**

# %%
plt.figure(figsize=(12, 4))
sns.scatterplot(x=ott['Runtime'], y=ott['Rotten Tomatoes'], color='blue')

plt.title("Relation Between Runtime and Rotten Tomatoes")
plt.xlabel("Runtime")
plt.ylabel("Rotten Tomatoes")

plt.show()

# %%
plt.figure(figsize=(12, 4))
sns.scatterplot(x=ott['Year'], y=ott['Runtime'], color='pink')

plt.title("Relation Between Year and Runtime")
plt.xlabel("Year")
plt.ylabel("Runtime")

plt.show()

# %% [markdown]
# #### **HeatMap for the IMDb, Rotten Tomatoes, Runtime and Year**

# %%
sns.heatmap(ott[['IMDb', 'Rotten Tomatoes', 'Runtime', 'Year']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### **Runtime Distribuation**

# %%
sns.histplot(ott['Runtime'], kde=True, color='blue')
plt.title('Runtime Distribution')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\sivaa\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# # **Interpretations from Streaming Services Data Analysis**
#
# **1. Dominant Language:** 🌐 **English** is the most prevalent language across all streaming services, reflecting its global reach and popularity.
#
# **2. Leading Country:** 🇺🇸 The **United States** leads in terms of the number of titles available, with **India** 💚 ranking 3rd, highlighting the significant content presence in these regions.
#
# **3. Top Streaming Service:** 📺 **Prime Video** has the largest number of movies, making it the most extensive service for movie content among the platforms analyzed.
#
# **4. Age Group Distribution:** 🎞️ Movies rated **18+** are predominant, making up 51% of the total movie content. This indicates a strong inclination towards adult content across all platforms.
#
# **5. Age Group Focus by Platform:** 🔞 **Netflix, Prime Video, Hulu, and Disney+** all have more than 50% of their movie content rated for 18+, emphasizing a trend towards adult-oriented programming.
#
# **6. Correlation Insights**
# - **IMDb and Rotten Tomatoes Ratings:** 📈 A positive correlation of **0.66** suggests that higher-rated movies on IMDb are likely to have good ratings on Rotten Tomatoes as well.
# - **Runtime and IMDb Ratings:** ⏱️ A correlation of **0.27** indicates a weak relationship, meaning that while runtime might have some influence, it is not a strong predictor of IMDb ratings.
#
# **7. Runtime Distribution:** 📊 The runtime of movies follows a **normal distribution**, which is useful for predictive modeling and setting benchmarks for content length.
#
# ### **8. Heatmap Analysis**
#
# **Heatmap for IMDb, Rotten Tomatoes, Year, and Runtime:** 🌡️ Heatmaps can provide visual insights into the relationships between different variables. For your dataset, a heatmap of IMDb ratings, Rotten Tomatoes ratings, Year, and Runtime can help identify patterns and correlations that might not be immediately apparent from numerical analysis alone.
#
# #### **Key Points to Look For**
# - **High Correlation Areas:** 🔍 Look for areas with stronger color intensities, indicating higher correlations.
# - **Low Correlation Areas:** 📉 Areas with lighter colors suggest weaker or no correlations.
